# %%
data_list=(10,10,20,30)
data_set={10,10,20,30}
sum(data_list)
# Out:
# 70

# %%
sum (data_set)
# Out:
# 60

# %%
fruits=['pineapple','mango','cherry','apple','orange','water melon']
new_fruits=['mango pie','apple juice','orange infused water']
indices=[1,3,4]
for i,new_value in zip (indices, new_fruits):
    fruits[i]= new_value
print (fruits)
# Out:
# ['pineapple', 'mango pie', 'cherry', 'apple juice', 'orange infused water', 'water melon']

# %%
names = ["Amina Bello", "John Okeke", "Fatima Musa", "Chinedu Obi", "Sola Ade",
    "Maryam Yusuf", "Emeka Nwosu", "Oluchi Eze", "Uche Chukwu", "Kemi Adebayo",
    "Ibrahim Lawal", "Ngozi Ojo", "Tunde Bakare", "Rita Eze", "Daniel Okafor",
    "Halima Bello", "Segun Afolabi", "Blessing Chukwu", "Femi Ade", "Chika Nwankwo"]
accounts = ["Savings", "Current", "Savings", "Fixed Deposit", "Savings",
    "Current", "Savings", "Fixed Deposit", "Current", "Savings",
    "Savings", "Current", "Fixed Deposit", "Savings", "Current",
    "Savings", "Current", "Savings", "Savings", "Fixed Deposit"]
balances = [ 250000, 120000, 54000, 1000000, 87500,
    300000, 450000, 1500000000, 200000, 95000,
    125000, 80000, 7500000, 60000, 180000,
    50000, 230000, 97000000, 11000000, 1300000]
branches = ["Lagos", "Abuja", "Kano", "Enugu", "Ibadan",
    "Lagos", "Abuja", "Kano", "Enugu", "Ibadan",
    "Lagos", "Abuja", "Kano", "Enugu", "Ibadan",
    "Lagos", "Abuja", "Kano", "Enugu", "Lagos"]

# %%
names = ["Amina Bello", "John Okeke", "Fatima Musa", "Chinedu Obi", "Sola Ade",
    "Maryam Yusuf", "Emeka Nwosu", "Oluchi Eze", "Uche Chukwu", "Kemi Adebayo",
    "Ibrahim Lawal", "Ngozi Ojo", "Tunde Bakare", "Rita Eze", "Daniel Okafor",
    "Halima Bello", "Segun Afolabi", "Blessing Chukwu", "Femi Ade", "Chika Nwankwo"]

# %%
names[8]="Atagamen Precious"
print (names)
# Out:
# ['Amina Bello', 'John Okeke', 'Fatima Musa', 'Chinedu Obi', 'Sola Ade', 'Maryam Yusuf', 'Emeka Nwosu', 'Oluchi Eze', 'Atagamen Precious', 'Kemi Adebayo', 'Ibrahim Lawal', 'Ngozi Ojo', 'Tunde Bakare', 'Rita Eze', 'Daniel Okafor', 'Halima Bello', 'Segun Afolabi', 'Blessing Chukwu', 'Femi Ade', 'Chika Nwankwo']

# %%
names[:5]=["Anosike Fidelia","Ojukwu zainab","Dara Simeon","Jessica Balogun","Fabian Buchi"]
names
new_names=["Jemila Andrews","Susan Bido","Dominion Gerald","Busan Dorcas"]
indices=[2,7,11,15]
for i, new_value in zip(indices,new_names):
    names[i]=new_value
print(names)
# Out:
# ['Anosike Fidelia', 'Ojukwu zainab', 'Jemila Andrews', 'Jessica Balogun', 'Fabian Buchi', 'Maryam Yusuf', 'Emeka Nwosu', 'Susan Bido', 'Atagamen Precious', 'Kemi Adebayo', 'Ibrahim Lawal', 'Dominion Gerald', 'Tunde Bakare', 'Rita Eze', 'Daniel Okafor', 'Busan Dorcas', 'Segun Afolabi', 'Blessing Chukwu', 'Femi Ade', 'Chika Nwankwo']

# %%
names[15:]=["Abiola Mariam","Osho Victoria","Abimbola Faustina","Yakub Bode"]
names
# Out:
# ['Anosike Fidelia',
#  'Ojukwu zainab',
#  'Jemila Andrews',
#  'Jessica Balogun',
#  'Fabian Buchi',
#  'Maryam Yusuf',
#  'Emeka Nwosu',
#  'Susan Bido',
#  'Atagamen Precious',
#  'Kemi Adebayo',
#  'Ibrahim Lawal',
#  'Dominion Gerald',
#  'Tunde Bakare',
#  'Rita Eze',
#  'Daniel Okafor',
#  'Abiola Mariam',
#  'Osho Victoria',
#  'Abimbola Faustina',
#  'Yakub Bode']

# %%
names.insert(6,"Gambo Warris")
names
# Out:
# ['Anosike Fidelia',
#  'Ojukwu zainab',
#  'Jemila Andrews',
#  'Jessica Balogun',
#  'Fabian Buchi',
#  'Maryam Yusuf',
#  'Gambo Warris',
#  'Emeka Nwosu',
#  'Susan Bido',
#  'Atagamen Precious',
#  'Kemi Adebayo',
#  'Ibrahim Lawal',
#  'Dominion Gerald',
#  'Tunde Bakare',
#  'Rita Eze',
#  'Daniel Okafor',
#  'Abiola Mariam',
#  'Osho Victoria',
#  'Abimbola Faustina',
#  'Yakub Bode']

# %%
names.append("Saheed Deji")
names
# Out:
# ['Anosike Fidelia',
#  'Ojukwu zainab',
#  'Jemila Andrews',
#  'Jessica Balogun',
#  'Fabian Buchi',
#  'Maryam Yusuf',
#  'Gambo Warris',
#  'Emeka Nwosu',
#  'Susan Bido',
#  'Atagamen Precious',
#  'Kemi Adebayo',
#  'Ibrahim Lawal',
#  'Dominion Gerald',
#  'Tunde Bakare',
#  'Rita Eze',
#  'Daniel Okafor',
#  'Abiola Mariam',
#  'Osho Victoria',
#  'Abimbola Faustina',
#  'Yakub Bode',
#  'Saheed Deji']

# %%
names.extend(["Felix Imoh","Freedom Christian","Haruna Fatima"])
names
# Out:
# ['Anosike Fidelia',
#  'Ojukwu zainab',
#  'Jemila Andrews',
#  'Jessica Balogun',
#  'Fabian Buchi',
#  'Maryam Yusuf',
#  'Gambo Warris',
#  'Emeka Nwosu',
#  'Susan Bido',
#  'Atagamen Precious',
#  'Kemi Adebayo',
#  'Ibrahim Lawal',
#  'Dominion Gerald',
#  'Tunde Bakare',
#  'Rita Eze',
#  'Daniel Okafor',
#  'Abiola Mariam',
#  'Osho Victoria',
#  'Abimbola Faustina',
#  'Yakub Bode',
#  'Saheed Deji',
#  'Felix Imoh',
#  'Freedom Christian',
#  'Haruna Fatima']

# %%
names.remove("Gambo Warris")
names
# Out:
# ['Anosike Fidelia',
#  'Ojukwu zainab',
#  'Jemila Andrews',
#  'Jessica Balogun',
#  'Fabian Buchi',
#  'Maryam Yusuf',
#  'Emeka Nwosu',
#  'Susan Bido',
#  'Atagamen Precious',
#  'Kemi Adebayo',
#  'Ibrahim Lawal',
#  'Dominion Gerald',
#  'Tunde Bakare',
#  'Rita Eze',
#  'Daniel Okafor',
#  'Abiola Mariam',
#  'Osho Victoria',
#  'Abimbola Faustina',
#  'Yakub Bode',
#  'Saheed Deji',
#  'Felix Imoh',
#  'Freedom Christian',
#  'Haruna Fatima']

# %%
while "Gambo Warris" in names:
    names.remove("Gambo Warris")
names
# Out:
# ['Anosike Fidelia',
#  'Ojukwu zainab',
#  'Jemila Andrews',
#  'Jessica Balogun',
#  'Fabian Buchi',
#  'Maryam Yusuf',
#  'Emeka Nwosu',
#  'Susan Bido',
#  'Atagamen Precious',
#  'Kemi Adebayo',
#  'Ibrahim Lawal',
#  'Dominion Gerald',
#  'Tunde Bakare',
#  'Rita Eze',
#  'Daniel Okafor',
#  'Abiola Mariam',
#  'Osho Victoria',
#  'Abimbola Faustina',
#  'Yakub Bode',
#  'Saheed Deji',
#  'Felix Imoh',
#  'Freedom Christian',
#  'Haruna Fatima']

# %%
names.pop(7)
names
# Out:
# ['Anosike Fidelia',
#  'Ojukwu zainab',
#  'Jemila Andrews',
#  'Jessica Balogun',
#  'Fabian Buchi',
#  'Maryam Yusuf',
#  'Emeka Nwosu',
#  'Atagamen Precious',
#  'Kemi Adebayo',
#  'Ibrahim Lawal',
#  'Dominion Gerald',
#  'Tunde Bakare',
#  'Rita Eze',
#  'Daniel Okafor',
#  'Abiola Mariam',
#  'Osho Victoria',
#  'Abimbola Faustina',
#  'Yakub Bode',
#  'Saheed Deji',
#  'Felix Imoh',
#  'Freedom Christian',
#  'Haruna Fatima']

# %%
del names[0:5]
names
# Out:
# ['Maryam Yusuf',
#  'Emeka Nwosu',
#  'Atagamen Precious',
#  'Kemi Adebayo',
#  'Ibrahim Lawal',
#  'Dominion Gerald',
#  'Tunde Bakare',
#  'Rita Eze',
#  'Daniel Okafor',
#  'Abiola Mariam',
#  'Osho Victoria',
#  'Abimbola Faustina',
#  'Yakub Bode',
#  'Saheed Deji',
#  'Felix Imoh',
#  'Freedom Christian',
#  'Haruna Fatima']

# %%
names2=['Anosike Fidelia',
 'Ojukwu zainab',
 'Jemila Andrews',
 'Jessica Balogun',
 'Fabian Buchi',
 'Emeka Nwosu',
 'Oluchi Eze',
 'Kemi Adebayo',
 'Ibrahim Lawal',
 'Ngozi Ojo',
 'Dominion Gerald',
 'Rita Eze',
 'Daniel Okafor',
 'Halima Bello',
 'Abiola Mariam',
 'Osho Victoria',
 'Abimbola Faustina',
 'Yakub Bode',
 'Saheed Deji',
 'Felix Imoh',
 'Freedom Christian',
 'Haruna Fatima']
names2.sort()
names2
# Out:
# ['Abimbola Faustina',
#  'Abiola Mariam',
#  'Anosike Fidelia',
#  'Daniel Okafor',
#  'Dominion Gerald',
#  'Emeka Nwosu',
#  'Fabian Buchi',
#  'Felix Imoh',
#  'Freedom Christian',
#  'Halima Bello',
#  'Haruna Fatima',
#  'Ibrahim Lawal',
#  'Jemila Andrews',
#  'Jessica Balogun',
#  'Kemi Adebayo',
#  'Ngozi Ojo',
#  'Ojukwu zainab',
#  'Oluchi Eze',
#  'Osho Victoria',
#  'Rita Eze',
#  'Saheed Deji',
#  'Yakub Bode']

# %%
state=("Lagos","Ebonyi","Delta","Edo","Niger","Imo")
print (state[1:4])
# Out:
# ('Ebonyi', 'Delta', 'Edo')

# %%
print (state[-1])
# Out:
# Imo

# %%
state=("Lagos","Ebonyi","Delta","Edo","Niger","Imo")
state_list=list(state)
print(state_list)
# Out:
# ['Lagos', 'Ebonyi', 'Delta', 'Edo', 'Niger', 'Imo']

# %%
state_list[3]="Benue"
print(state_list)
# Out:
# ['Lagos', 'Ebonyi', 'Delta', 'Benue', 'Niger', 'Imo']

# %%
state=tuple(state_list)
print (state)
# Out:
# ('Lagos', 'Ebonyi', 'Delta', 'Benue', 'Niger', 'Imo')

# %%
state_1=("Anambra","Imo","Ebonyi","Abia")
state_2=("Delta","Edo","Cross Rivers")
state_3= state_1+state_2
state_3
# Out:
# ('Anambra', 'Imo', 'Ebonyi', 'Abia', 'Delta', 'Edo', 'Cross Rivers')

# %%
state_4=state_3*2
state_4
# Out:
# ('Anambra',
#  'Imo',
#  'Ebonyi',
#  'Abia',
#  'Delta',
#  'Edo',
#  'Cross Rivers',
#  'Anambra',
#  'Imo',
#  'Ebonyi',
#  'Abia',
#  'Delta',
#  'Edo',
#  'Cross Rivers')

# %%
student={"name":"Godiya","age":19,"subject":"maths","grades":[79,95]}
print(student)
# Out:
# {'name': 'Godiya', 'age': 19, 'subject': 'maths', 'grades': [79, 95]}

# %%
student=dict (name="Godiya",age=19,subject="English",grades=[75,98])
student
# Out:
# {'name': 'Godiya', 'age': 19, 'subject': 'English', 'grades': [75, 98]}

# %%
student["grades"]
# Out:
# [75, 98]

# %%
student["subject"]
# Out:
# 'English'

# %%
student["name"]
# Out:
# 'Godiya'

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'subject', 'grades'])

# %%
student.values()
# Out:
# dict_values(['Godiya', 19, 'English', [75, 98]])

# %%
student.items()
# Out:
# dict_items([('name', 'Godiya'), ('age', 19), ('subject', 'English'), ('grades', [75, 98])])

# %%
student["name"]="Precious"
student
# Out:
# {'name': 'Precious', 'age': 19, 'subject': 'English', 'grades': [75, 98]}

# %%
student.update(name="Haruna")
student
# Out:
# {'name': 'Haruna', 'age': 19, 'subject': 'English', 'grades': [75, 98]}

# %%
student={"name":"Godiya","age":19,"subject":"maths","grades":[79,95]}
student["Class"]="SS2"
student
# Out:
# {'name': 'Godiya',
#  'age': 19,
#  'subject': 'maths',
#  'grades': [79, 95],
#  'Class': 'SS2'}

# %%
student={'name': 'Godiya','age': 19,'subject': 'maths','grades': [79, 95],'Class': 'SS2'}
student.update({"gender":"male"})
print(student)
student.pop("Class")
print(student)
# Out:
# {'name': 'Godiya', 'age': 19, 'subject': 'maths', 'grades': [79, 95], 'Class': 'SS2', 'gender': 'male'}
# {'name': 'Godiya', 'age': 19, 'subject': 'maths', 'grades': [79, 95], 'gender': 'male'}

# %%
student={'name': 'Godiya', 'age': 19, 'subject': 'maths', 'grades': [79, 95], 'Class': 'SS2', 'gender': 'male'}
student.popitem()
print (student)
# Out:
# {'name': 'Godiya', 'age': 19, 'subject': 'maths', 'grades': [79, 95], 'Class': 'SS2'}

# %%
names = ["Amina Bello", "John Okeke", "Fatima Musa", "Chinedu Obi", "Sola Ade",
    "Maryam Yusuf", "Emeka Nwosu", "Oluchi Eze", "Uche Chukwu", "Kemi Adebayo",
    "Ibrahim Lawal", "Ngozi Ojo", "Tunde Bakare", "Rita Eze", "Daniel Okafor",
    "Halima Bello", "Segun Afolabi", "Blessing Chukwu", "Femi Ade", "Chika Nwankwo"]
accounts = ["Savings", "Current", "Savings", "Fixed Deposit", "Savings",
    "Current", "Savings", "Fixed Deposit", "Current", "Savings",
    "Savings", "Current", "Fixed Deposit", "Savings", "Current",
    "Savings", "Current", "Savings", "Savings", "Fixed Deposit"]
balances = [ 250000, 120000, 54000, 1000000, 87500,
    300000, 450000, 1500000000, 200000, 95000,
    125000, 80000, 7500000, 60000, 180000,
    50000, 230000, 97000000, 11000000, 1300000]
branches = ["Lagos", "Abuja", "Kano", "Enugu", "Ibadan",
    "Lagos", "Abuja", "Kano", "Enugu", "Ibadan",
    "Lagos", "Abuja", "Kano", "Enugu", "Ibadan",
    "Lagos", "Abuja", "Kano", "Enugu", "Lagos"]
bank_data=list(zip(names,accounts,balances,branches))
print (bank_data)
# Out:
# [('Amina Bello', 'Savings', 250000, 'Lagos'), ('John Okeke', 'Current', 120000, 'Abuja'), ('Fatima Musa', 'Savings', 54000, 'Kano'), ('Chinedu Obi', 'Fixed Deposit', 1000000, 'Enugu'), ('Sola Ade', 'Savings', 87500, 'Ibadan'), ('Maryam Yusuf', 'Current', 300000, 'Lagos'), ('Emeka Nwosu', 'Savings', 450000, 'Abuja'), ('Oluchi Eze', 'Fixed Deposit', 1500000000, 'Kano'), ('Uche Chukwu', 'Current', 200000, 'Enugu'), ('Kemi Adebayo', 'Savings', 95000, 'Ibadan'), ('Ibrahim Lawal', 'Savings', 125000, 'Lagos'), ('Ngozi Ojo', 'Current', 80000, 'Abuja'), ('Tunde Bakare', 'Fixed Deposit', 7500000, 'Kano'), ('Rita Eze', 'Savings', 60000, 'Enugu'), ('Daniel Okafor', 'Current', 180000, 'Ibadan'), ('Halima Bello', 'Savings', 50000, 'Lagos'), ('Segun Afolabi', 'Current', 230000, 'Abuja'), ('Blessing Chukwu', 'Savings', 97000000, 'Kano'), ('Femi Ade', 'Savings', 11000000, 'Enugu'), ('Chika Nwankwo', 'Fixed Deposit', 1300000, 'Lagos')]

# %%
accounts.count("Savings")
# Out:
# 10

# %%
accounts.count("Abuja")
# Out:
# 0

# %%
nums=[1,2,3]
print(nums[0])
# Out:
# 1

# %%
t=[1,2,3]
t[0]=5
print (t)
# Out:
# [5, 2, 3]

# %%
s={1,2,2,3}
print(s)
# Out:
# {1, 2, 3}

# %%
w=[1,2,3]
w.append(4)
print(w)
# Out:
# [1, 2, 3, 4]

# %%
s={1,2,2,3}
print(len(s))
# Out:
# 3
