# %% [markdown]
# # Dats Structure
#
# This exercise is designed to reinforce students’ understanding of Python data structures: lists, tuples, dictionaries, and sets. Through a combination of practical coding tasks and conceptual questions, learners will apply their knowledge of how these structures are created, accessed, modified, and used in real-world scenarios.
#
# By completing this exercise, students will strengthen their practical programming skills and deepen their understanding of how data structures impact performance, organization, and problem-solving in Python applications.

# %% [markdown]
# #### Create a list called `colours` containing: "red", "blue", "green", "yellow"

# %%
# YOUR CODE HERE
colours=["red","blue","green","yellow"]
print(colours)


#raise NotImplementedError()
# Out:
# ['red', 'blue', 'green', 'yellow']

# %% [markdown]
# #### Create a list called `colours` containing: "red", "blue", "green", "yellow" and access the first item on the list. Store the last item in a variable called `first_colour`

# %%
# YOUR CODE HERE
colours=["red","blue","green","yellow"]
print(colours[0])
first_colour=colours[-1]
print(first_colour)

#raise NotImplementedError()
# Out:
# red
# yellow

# %% [markdown]
# #### Create a list called `colours` containing: "red", "blue", "green", "yellow" and access the last item on the list. Store the last item in a variable called `last_colour`

# %%
# YOUR CODE HERE
colours=["red","blue","green","yellow"]
print(colours[-1])
last_colour=colours[-1]
print(last_colour)
#raise NotImplementedError()
# Out:
# yellow
# yellow

# %% [markdown]
# #### Create a list called `numbers` containing: 10, 20, 30, 40, 50, 60 and access the first three numbers. Store the items in a variable called `first_three`

# %%
# YOUR CODE HERE
numbers=[10,20,30,40,50,60]
print(numbers)
print(numbers[:3])
first_three=numbers[:3]
print(first_three)

#raise NotImplementedError()
# Out:
# [10, 20, 30, 40, 50, 60]
# [10, 20, 30]
# [10, 20, 30]

# %% [markdown]
# #### Create a list called `numbers` containing: 10, 20, 30, 40, 50, 60 and access the last three numbers. Store the items in a variable called `last_three`

# %%
# YOUR CODE HERE
numbers=[10,20,30,40,50,60]
print(numbers)
print(numbers[3:])
last_three=numbers[3:]
print(last_three)

#raise NotImplementedError()
# Out:
# [10, 20, 30, 40, 50, 60]
# [40, 50, 60]
# [40, 50, 60]

# %% [markdown]
# #### Create a list called `cities` containing: "Lagos", "Abuja", "Kano", "Ibadan" and replace "Kano" with "Port Harcourt".

# %%
# YOUR CODE HERE
cities=["Lagos","Abuja","Kano","Ibadan"]
print(cities)
cities[2]="Port Harcourt"
print (cities)
#raise NotImplementedError()
# Out:
# ['Lagos', 'Abuja', 'Kano', 'Ibadan']
# ['Lagos', 'Abuja', 'Port Harcourt', 'Ibadan']

# %% [markdown]
# #### Create a list called `fruits` containing "apple", "banana". Write a code to add "grape" to the end of this list:

# %%
# YOUR CODE HERE
fruits=["apples","banana"]
print(fruits)
fruits.append("grape")
print(fruits)
#raise NotImplementedError()
# Out:
# ['apples', 'banana']
# ['apples', 'banana', 'grape']

# %% [markdown]
# #### Create a list called `fruits` containing "apple", "banana", "grape". Insert "cherry" at index 1

# %%
# YOUR CODE HERE
fruits=['apples', 'banana', 'grape']
print(fruits)
fruits.insert(1,"cherry")
print(fruits)

#raise NotImplementedError()
# Out:
# ['apples', 'banana', 'grape']
# ['apples', 'cherry', 'banana', 'grape']

# %% [markdown]
# #### Create a list called `items` containing "pen", "book", "eraser", "pencil". Remove the third item from:

# %%
# YOUR CODE HERE
items=["pen","book","eraser","pencil"]
print(items)
items.pop(2)
print(items)
#raise NotImplementedError()
# Out:
# ['pen', 'book', 'eraser', 'pencil']
# ['pen', 'book', 'pencil']

# %% [markdown]
# ### Create a list called `names` containing "John", "Ada", "Zainab", "Michael". Sort this list alphabetically:

# %%
# YOUR CODE HERE
names=["John","Ada","Zainab","Michael"]
print(names)
names.sort()
print(names)
#raise NotImplementedError()
# Out:
# ['John', 'Ada', 'Zainab', 'Michael']
# ['Ada', 'John', 'Michael', 'Zainab']

# %% [markdown]
# ### Create a tuple called `country` containing only `Nigeria`.

# %%
# YOUR CODE HERE
country=("Nigeria",)
print(country)
#raise NotImplementedError()
# Out:
# ('Nigeria',)

# %% [markdown]
# ### Create a tuple called `animals` containing only "dog", "cat", "goat". Write code to remove "cat" from the tuple.

# %%
# YOUR CODE HERE
animals=("dog","cat","goat")
print(animals)
animal_list=list(animals)
print(animal_list)
animal_list.remove("cat")
print(animal_list)
animals=tuple(animal_list)
print(animals)
#raise NotImplementedError()
# Out:
# ('dog', 'cat', 'goat')
# ['dog', 'cat', 'goat']
# ['dog', 'goat']
# ('dog', 'goat')

# %% [markdown]
# ### Create Dictionary
#
# #### Create a dictionary called `student` containing:
#
# - name: "Ada"
#
# - age: 20
#
# - course: "Computer Science"

# %%
# YOUR CODE HERE
student={"name":"Ada","age":20,"course":"computer science"}
print(student)
#raise NotImplementedError()
# Out:
# {'name': 'Ada', 'age': 20, 'course': 'computer science'}

# %% [markdown]
# ### Create Dictionary
#
# #### Create a dictionary called `car` containing. Write code to print the car brand
#
# - brand: Toyota,
# - year: 2022,
# - colour: black

# %%
# YOUR CODE HERE
car={"brand":"Toyota","year":2022,"colour":"black"}
print(car)
#print(car["brand"])

#raise NotImplementedError()
# Out:
# {'brand': 'Toyota', 'year': 2022, 'colour': 'black'}

# %% [markdown]
# ### Create Dictionary
#
# #### Create a dictionary called `car` containing. Write code to print the car year
#
# - brand: Toyota,
# - year: 2022,
# - colour: black

# %%
# YOUR CODE HERE
car={"brand":"Toyota","year":2022,"colour":"black"}
print(car)
print(car["year"])
#raise NotImplementedError()
# Out:
# {'brand': 'Toyota', 'year': 2022, 'colour': 'black'}
# 2022

# %% [markdown]
# ### Using the dictionary above, change the car colour to "white".

# %%
# YOUR CODE HERE
car.update(colour="white")
print(car)
#raise NotImplementedError()
# Out:
# {'brand': 'Toyota', 'year': 2022, 'colour': 'white'}

# %% [markdown]
# ### Add a new key "price" with value 5000000 to the car dictionary.

# %%
# YOUR CODE HERE
car["price"] = 5000000
print(car)
#raise NotImplementedError()
# Out:
# {'brand': 'Toyota', 'year': 2022, 'colour': 'white', 'price': 5000000}

# %% [markdown]
# ### Remove the key "year" from the dictionary.

# %%
# YOUR CODE HERE
car.pop("year")
print(car)

#raise NotImplementedError()
# Out:
# {'brand': 'Toyota', 'colour': 'white', 'price': 5000000}

# %% [markdown]
# ### Write code to check if "banana" exists in the set.
#
# fruits = {"apple", "banana", "mango "}
#
# print "yes"

# %%
# YOUR CODE HERE
fruits = {"apple", "banana", "mango"}

if "banana" in fruits:
    print("yes")
#raise NotImplementedError()
# Out:
# yes

# %% [markdown]
# ### Add "orange" to the set above.

# %%
# YOUR CODE HERE
fruits.add("orange")
print(fruits)
#raise NotImplementedError()
# Out:
# {'orange', 'banana', 'mango', 'apple'}

# %% [markdown]
# ## Analyse this data

# %%
students=module_1a-module_1b
print(students)
# Out:
# {'favouradaku.charles@gmail.com', 'okeoghenejenifer@gmail.com', 'eronlaneghonghon@gmail.com'}

# %% [markdown]
# ### Total unique students

# %%
# YOUR CODE HERE
unique=module_1a.union(module_1b)
print(unique)
#raise NotImplementedError()
# Out:
# {'khadijatoyedeji@gmail.com', 'ochioma408@gmail.com', 'adimaogloria@gmail.com', 'bakaremistura111@gmail.com', 'abichequeen@gmail.com', 'akinboyetola@gmail.com', 'khadijatopajobi@gmail.com', 'preciousose22@gmail.com', 'saobanramotallahi09@gmail.com', 'excelanurithompson@gmail.com', 'chukwuemekapreciouschisom@gmail.com', 'loiszy5@gmail.com', 'dorcasoluwaseun16@gmail.com', 'celinenwachukwu1@gmail.com', 'toluesther2222@gmail.com', 'ayomideeli2002@gmail.com', 'ashiruodunayo@gmail.com', 'mabelajoma@gmail.com', 'oziomaebube9@gmail.com', 'lauraeseoheiyere@gmail.com', 'okeoghenejenifer@gmail.com', 'jamesifeoma95@gmail.com', 'courageonyinye2002@gmail.com', 'eronlaneghonghon@gmail.com', 'arilomoislamiyat@gmail.com', 'ruthpaul8185@gmail.com', 'adaezechiazorchime@gmail.com', 'victorianwogo@gmail.com', 'jerushausiju114@gmail.com', 'inametimercy92@gmail.com', 'aanuakinleye@gmail.com', 'favouradaku.charles@gmail.com', 'davidsarah008@gmail.com', 'okunugagladys@gmail.com'}

# %% [markdown]
# ### Students who answered both exercises

# %%
# YOUR CODE HERE
both=module_1a.intersection(module_1b)
print(both)
#raise NotImplementedError()
# Out:
# {'khadijatoyedeji@gmail.com', 'ochioma408@gmail.com', 'adimaogloria@gmail.com', 'bakaremistura111@gmail.com', 'abichequeen@gmail.com', 'akinboyetola@gmail.com', 'khadijatopajobi@gmail.com', 'saobanramotallahi09@gmail.com', 'preciousose22@gmail.com', 'excelanurithompson@gmail.com', 'chukwuemekapreciouschisom@gmail.com', 'loiszy5@gmail.com', 'dorcasoluwaseun16@gmail.com', 'celinenwachukwu1@gmail.com', 'toluesther2222@gmail.com', 'ayomideeli2002@gmail.com', 'ashiruodunayo@gmail.com', 'mabelajoma@gmail.com', 'oziomaebube9@gmail.com', 'lauraeseoheiyere@gmail.com', 'jamesifeoma95@gmail.com', 'courageonyinye2002@gmail.com', 'arilomoislamiyat@gmail.com', 'ruthpaul8185@gmail.com', 'adaezechiazorchime@gmail.com', 'victorianwogo@gmail.com', 'jerushausiju114@gmail.com', 'inametimercy92@gmail.com', 'aanuakinleye@gmail.com', 'davidsarah008@gmail.com', 'okunugagladys@gmail.com'}

# %% [markdown]
# ### Returns only items NOT contained in both sets

# %%
# YOUR CODE HERE
not_both=module_1a.difference(module_1b)
print(not_both)
#raise NotImplementedError()
# Out:
# {'favouradaku.charles@gmail.com', 'okeoghenejenifer@gmail.com', 'eronlaneghonghon@gmail.com'}
